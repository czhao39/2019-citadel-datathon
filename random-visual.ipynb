# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
seds = pd.read_csv('data/seds.csv')

# %%
seds.head()
# Out:
#    year    msn state_name state_code  \
# 0  1960  ABICB     Alaska         AK
# 1  1961  ABICB     Alaska         AK
# 2  1962  ABICB     Alaska         AK
# 3  1963  ABICB     Alaska         AK
# 4  1964  ABICB     Alaska         AK
#
#                                          description energy_bin  value  \
# 0  Aviation gasoline blending components consumed...  Petroleum    0.0
# 1  Aviation gasoline blending components consumed...  Petroleum    0.0
# 2  Aviation gasoline blending components consumed...  Petroleum    0.0
# 3  Aviation gasoline blending components consumed...  Petroleum    0.0
# 4  Aviation gasoline blending components consumed...  Petroleum    0.0
#
#           unit
# 0  Billion Btu
# 1  Billion Btu
# 2  Billion Btu
# 3  Billion Btu
# 4  Billion Btu

# %%
seds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711736 entries, 0 to 1711735
# Data columns (total 8 columns):
# year           int64
# msn            object
# state_name     object
# state_code     object
# description    object
# energy_bin     object
# value          float64
# unit           object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 104.5+ MB

# %%
seds.columns
# Out:
# Index([u'year', u'msn', u'state_name', u'state_code', u'description',
#        u'energy_bin', u'value', u'unit'],
#       dtype='object')

# %%
sns.pairplot(seds)
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.heatmap(seds.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# ## Vehicles

# %%
vehicles = pd.read_csv('data/vehicles.csv')

# %%
vehicles.head()
# Out:
#    petrol_consump  petrol_consump_alt  city_mileage  city_mileage_alt  \
# 0       15.695714                 0.0           0.0               0.0
# 1       29.964545                 0.0           0.0               0.0
# 2       12.207778                 0.0           0.0               0.0
# 3       29.964545                 0.0           0.0               0.0
# 4       17.347895                 0.0           0.0               0.0
#
#    city_electricity  co2  co2_alt  fuel_cost  fuel_cost_alt         fuel_type  \
# 0               0.0  NaN      NaN     1600.0            0.0  Regular Gasoline
# 1               0.0  NaN      NaN     3050.0            0.0  Regular Gasoline
# 2               0.0  NaN      NaN     1250.0            0.0  Regular Gasoline
# 3               0.0  NaN      NaN     3050.0            0.0  Regular Gasoline
# 4               0.0  NaN      NaN     2300.0            0.0  Premium Gasoline
#
#   fuel_type_alt        make                model    vehicle_class  year  \
# ...

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40789 entries, 0 to 40788
# Data columns (total 16 columns):
# petrol_consump        40789 non-null float64
# petrol_consump_alt    40789 non-null float64
# city_mileage          40789 non-null float64
# city_mileage_alt      40789 non-null float64
# city_electricity      40789 non-null float64
# co2                   8835 non-null float64
# co2_alt               608 non-null float64
# fuel_cost             40789 non-null float64
# fuel_cost_alt         40789 non-null float64
# fuel_type             40789 non-null object
# fuel_type_alt         1589 non-null object
# make                  40789 non-null object
# model                 40789 non-null object
# vehicle_class         40789 non-null object
# year                  40789 non-null int64
# you_saved_spend       40789 non-null float64
# dtypes: float64(10), int64(1), object(5)
# memory usage: 5.0+ MB

# %%
vehicles.describe()
# Out:
#        petrol_consump  petrol_consump_alt  city_mileage  city_mileage_alt  \
# count    40789.000000        40789.000000  40789.000000      40789.000000
# mean        17.321467            0.221292      5.787023          0.495305
# std          4.604380            1.144292     11.306780          4.819944
# min          0.060000            0.000000      0.000000          0.000000
# 25%         14.330870            0.000000      0.000000          0.000000
# 50%         16.480500            0.000000      0.000000          0.000000
# 75%         19.388824            0.000000     13.501600          0.000000
# max         47.087143           18.311667    150.000000        145.083500
#
#        city_electricity          co2     co2_alt     fuel_cost  fuel_cost_alt  \
# count      40789.000000  8835.000000  608.000000  40789.000000   40789.000000
# mean           0.289451   399.262932  463.087171   1938.316703     100.655814
# ...

# %%
sns.heatmap(vehicles.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.pairplot(vehicles)

# %% [markdown]
# ## Air Concentration

# %%
air = pd.read_csv('data/air_concentrations.csv')

# %%
air.head()
# Out:
#     latitude  longitude state_code    county              date_on  \
# 0  39.988309 -79.251573         PA  Somerset  01/03/2000 16:37:00
# 1  39.988309 -79.251573         PA  Somerset  01/10/2000 16:09:00
# 2  39.988309 -79.251573         PA  Somerset  01/17/2000 20:07:00
# 3  39.988309 -79.251573         PA  Somerset  01/24/2000 21:11:00
# 4  39.988309 -79.251573         PA  Somerset  01/31/2000 16:40:00
#
#               date_off    TSO4    TNH4      CA      MG      NA       K  CL  \
# 0  01/10/2000 16:03:00  2.3406  0.7764  0.1267  0.0144  0.1740  0.0536 NaN
# 1  01/17/2000 19:57:00  1.7681  0.9436  0.2127  0.0272  0.1700  0.0452 NaN
# 2  01/24/2000 21:00:00  3.7462  0.9171  0.1410  0.0220  0.1805  0.0534 NaN
# 3  01/31/2000 16:33:00  3.6490  1.4580  0.1359  0.0217  0.3100  0.0534 NaN
# 4  02/07/2000 16:06:00  3.8717  0.8672  0.0944  0.0146  0.1143  0.0391 NaN
#
#      NSO4   NHNO3     WSO2    WNO3  total_SO2  total_NO3  flow_volume
# ...

# %%
sns.heatmap(air.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
pa = air.loc[air['state_code'] == 'PA']
pa
# Out:
#         latitude  longitude state_code    county              date_on  \
# 0      39.988309 -79.251573         PA  Somerset  01/03/2000 16:37:00
# 1      39.988309 -79.251573         PA  Somerset  01/10/2000 16:09:00
# 2      39.988309 -79.251573         PA  Somerset  01/17/2000 20:07:00
# 3      39.988309 -79.251573         PA  Somerset  01/24/2000 21:11:00
# 4      39.988309 -79.251573         PA  Somerset  01/31/2000 16:40:00
# 5      39.988309 -79.251573         PA  Somerset  02/07/2000 16:13:00
# 6      39.988309 -79.251573         PA  Somerset  02/14/2000 16:09:00
# 7      39.988309 -79.251573         PA  Somerset  02/21/2000 17:26:00
# 8      39.988309 -79.251573         PA  Somerset  02/28/2000 17:53:00
# 9      39.988309 -79.251573         PA  Somerset  03/06/2000 16:20:00
# 10     39.988309 -79.251573         PA  Somerset  03/13/2000 15:47:00
# 11     39.988309 -79.251573         PA  Somerset  03/20/2000 17:19:00
# ...

# %%
pa['date_on'] = pd.to_datetime(pa['date_on'])
# Out:
# /Users/Sammy/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.pairplot(pa)

# %%
sns.heatmap(pa.corr(), annot = True)

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84900 entries, 0 to 84899
# Data columns (total 20 columns):
# latitude       84900 non-null float64
# longitude      84900 non-null float64
# state_code     84900 non-null object
# county         82783 non-null object
# date_on        84900 non-null object
# date_off       84900 non-null object
# TSO4           82378 non-null float64
# TNH4           82377 non-null float64
# CA             82296 non-null float64
# MG             82298 non-null float64
# NA             82294 non-null float64
# K              82210 non-null float64
# CL             67363 non-null float64
# NSO4           82388 non-null float64
# NHNO3          82388 non-null float64
# WSO2           82378 non-null float64
# WNO3           8920 non-null float64
# total_SO2      82369 non-null float64
# total_NO3      82380 non-null float64
# flow_volume    82861 non-null float64
# dtypes: float64(16), object(4)
# memory usage: 13.0+ MB

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
list(pa)
# Out:
# ['latitude',
#  'longitude',
#  'state_code',
#  'county',
#  'date_on',
#  'date_off',
#  'TSO4',
#  'TNH4',
#  'CA',
#  'MG',
#  'NA',
#  'K',
#  'CL',
#  'NSO4',
#  'NHNO3',
#  'WSO2',
#  'WNO3',
#  'total_SO2',
#  'total_NO3',
#  'flow_volume']

# %%
X = pa[['date_on', 'date_off']]
y = pa['NSO4']

# %%
lm.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1a1070dd988b> in <module>()
# ----> 1 lm.fit(X,y)
#
# /Users/Sammy/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /Users/Sammy/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
power = pd.read_csv('data/power_plants.csv')

# %%
power.head()
# Out:
#    longitude   latitude          plant_name      utility_name  \
# 0 -87.356823  33.458665        Bankhead Dam  Alabama Power Co
# 1 -88.010300  31.006900               Barry  Alabama Power Co
# 2 -86.283056  32.583889  Walter Bouldin Dam  Alabama Power Co
# 3 -85.970800  34.012800             Gadsden  Alabama Power Co
# 4 -87.196486  33.644344              Gorgas  Alabama Power Co
#
#         sector_name       city  county state_name primary_source  total_power  \
# 0  Electric Utility  Northport      as    Alabama  hydroelectric         56.0
# 1  Electric Utility      Bucks  Mobile    Alabama           coal       2160.5
# 2  Electric Utility   Wetumpka  Elmore    Alabama  hydroelectric        225.9
# 3  Electric Utility    Gadsden  Etowah    Alabama    natural gas        130.0
# 4  Electric Utility    Parrish  Walker    Alabama           coal       1034.0
#
#                         source_description  \
# 0                                        g
# ...

# %%
sns.heatmap(power.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
power['state_name'].astype('category')
# Out:
# 0             Alabama
# 1             Alabama
# 2             Alabama
# 3             Alabama
# 4             Alabama
# 5               Texas
# 6             Alabama
# 7             Alabama
# 8             Alabama
# 9             Alabama
# 10            Alabama
# 11            Alabama
# 12            Alabama
# 13            Alabama
# 14            Alabama
# 15            Alabama
# 16            Alabama
# 17            Alabama
# 18            Alabama
# 19          Minnesota
# 20         California
# 21            Alabama
# 22            Alabama
# 23            Alabama
# 24            Alabama
# 25            Alabama
# 26          Louisiana
# 27            Alabama
# 28           Kentucky
# 29            Alabama
#             ...
# 7908       California
# 7909         Maryland
# 7910     Pennsylvania
# 7911    New Hampshire
# 7912    Massachusetts
# 7913         New York
# 7914       California
# 7915        Tennessee
# 7916       California
# 7917       California
# ...

# %%
power.dtypes
# Out:
# longitude             float64
# latitude              float64
# plant_name             object
# utility_name           object
# sector_name            object
# city                   object
# county                 object
# state_name             object
# primary_source         object
# total_power           float64
# source_description     object
# tech_description       object
# dtype: object
